# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    Puerto Ayora  -0.7393  -90.3518     80.56        80          86
# 1        1          Albany  42.6001  -73.9662     41.23        88         100
# 2        2  Campbell River  50.0163 -125.2446     54.45        25          29
# 3        3       Makubetsu  45.3714  141.8211     42.60        80          79
# 4        4           Tiksi  71.6872  128.8694      0.00        98          66
#
#    Wind Speed Country           Date
# 0        7.70      EC  4/16/22 21:11
# 1        1.01      US  4/16/22 21:07
# 2        2.77      CA  4/16/22 21:08
# 3       20.54      JP  4/16/22 21:11
# 4        4.23      RU  4/16/22 21:11

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2)
# Add the heatmap layer.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#6.5.2

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0  Puerto Ayora  -0.7393  -90.3518     80.56        80          86
# 5         5          Hilo  19.7297 -155.0900     77.29        97         100
# 6         6    Georgetown   5.4112  100.3354     80.53        89          20
# 8         8        Avarua -21.2078 -159.7750     80.65        83          20
# 10       10       Salalah  17.0151   54.0924     80.69        89          40
# 11       11      Bengkulu  -3.8004  102.2655     76.89        89         100
# 14       14  Komsomolskiy  40.4272   71.7189     69.37        22           7
# 16       16     Kavaratti  10.5669   72.6420     83.30        73          21
# 20       20         Buala  -8.1450  159.5921     81.00        79         100
# 21       21        Atuona  -9.8000 -139.0333     79.25        78          19
#
#     Wind Speed Country           Date
# 0         7.70      EC  4/16/22 21:11
# 5         3.44      US  4/16/22 21:11
# 6         0.00      MY  4/16/22 21:08
# 8         5.75      CK  4/16/22 21:11
# 10        2.30      OM  4/16/22 21:11
# 11        3.00      ID  4/16/22 21:11
# 14        4.09      UZ  4/16/22 21:11
# 16        3.36      IN  4/16/22 21:11
# 20        5.08      SB  4/16/22 21:11
# 21       15.97      PF  4/16/22 21:11

# %%
preferred_cities_df.count()
# Out:
# City_ID       303
# City          303
# Lat           303
# Lng           303
# Max Temp      303
# Humidity      303
# Cloudiness    303
# Wind Speed    303
# Country       300
# Date          303
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 0   Puerto Ayora      EC     80.56  -0.7393  -90.3518
# 5           Hilo      US     77.29  19.7297 -155.0900
# 6     Georgetown      MY     80.53   5.4112  100.3354
# 8         Avarua      CK     80.65 -21.2078 -159.7750
# 10       Salalah      OM     80.69  17.0151   54.0924
# 11      Bengkulu      ID     76.89  -3.8004  102.2655
# 14  Komsomolskiy      UZ     69.37  40.4272   71.7189
# 16     Kavaratti      IN     83.30  10.5669   72.6420
# 20         Buala      SB     81.00  -8.1450  159.5921
# 21        Atuona      PF     79.25  -9.8000 -139.0333

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAS_cauauAkH0vhybQP4NHJkTZn4Anyf_zFMIl7yyAm8afqY_qHEkvmlLM39QcgjemhOSM9Pu4kXgVtpt_HaGiTS1MSw8dtPFy83gdKu3UkU8j4ogLn8lMaDDnVY2qutC13xekKI2lXGrkTkS_WR2UCzQ8L8jIxxShz_VMrlPzEuH-9kEXoP6Rkw155UzQdQW-ql-1JXaB_DC4gYKpzRqoFahFQKMzZ--ezrGdLUoikm83Y6J5PM8VsHUzqnO7eQiqfglg4LXcuq15lNLjlbZ15u1fvuvtpJFIbGZkE2xiUxomRCwrlJ4dDDdDSSHWbOZwrfhA6ub1dGCC9-nIhzGcB2rQM3tGiB2cF680P0OyQYJ8aJ2RThlSjMcU8XeYqpBFcEOuRV7njkgTPCBYDy04jphDIB4JRH8CGGZfngdLyxYHnY4Jo8uQ9',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uECVTVFTu295w5FY6ml11vT26dmw8wX-OgM4BOQFgwtn_utw2qLdwFNqM-XSNi2SlD3Z1PIE5K8bGCPR6ByABadJpnk9s-PPp1dfe0pJ1l_5bJV6mUbdUTaEJlHOj9-5tGXEdPIHu1E0J-GNBu42mVu_-dOpttUvw0uOzaP3K--tnbDm',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 324,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEBmj25mgfkeLqt5JoIeSUIyUKz-lpUgeIoZ_L5dFCArOid8MFgA0KNl-txH_440D1QRogWSIAhPph5-Kuyxem5pm7eM4Leiy9qW7hYyKkw2QGYaqO-loctRo5YJTCzxKFgt0lDDRVnYVxmJms-AzFkt8SDHy5edSMUd6eHfwbWGPBf2',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.7,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 727,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617746302915,
#       'lng': 2.347927730291502},
#      'southwest': {'lat': 48.8590766697085, 'lng': 2.345229769708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 853,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEDF2OosRS-wBdeUSYpjORDKF-FnG6TkJN1yEYcdt0RyLnCBxNt_kyz3SuFGT-l2lbnVMS_Myinko3paP0-u7EsWxZc31WYyhqfGnHP6uUGBMOoz8SuH1vYMrrCm2ssvAHP2FQ2QgUmFjP0ouTQc-Kp6fESoE9CMC52st1XnlcfrJJV4',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'lodging',
#     'local_government_office',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 905,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEA1XkNVPefAsrakc26XH0yCUSXkWyWfP_9bVlh2IweAQpj3ilIsr8XWlIRDpxsRqgw4qYd84GiWnvYABNh46gKoKYH1MR7pbZ1Rx5axV3kWt4hQcFp3_Cri1iMfMJ28bqyXoYHAs4MXoM5LF6vck1g9Dgn1XHZGXhP7X1T8PWaT6dBj',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2422,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.8617009802915,
#       'lng': 2.345443780291502},
#      'southwest': {'lat': 48.8590030197085, 'lng': 2.342745819708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEDoEqp5kS2PFLQp6kULAwJ5_j6tAhEVUIPZcZSbVtXIWJbotgbgdxDHfyp3rrHcH_LIlDFXB0ZJIM5mvy_JjwC07BE1xEJ4iNWq7hLhY-deYkrRLMC5WjdSkR5A3gX_Cn_iSl1Rr6C3wgBwaqVBZNJAY3jj0nw9sIDQFRYa9EPk8loe',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 290,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uECeCWR292uMuRVjO-pHcyGqMVb10xpGYxE_keeyYEWL9YFCmPCa2SV6enCaYZuo1PFiqhjyj2nBRKOa6HlodphQpiWG_LB-kCwtRkOSHOH5VHBZbcdA2EZAh6Deae-KrvDwpqG8yZdr9KGIg6Mcx4Agw-ynKDX-nfOMYdKcVjt0aNPJ',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'lodging',
#     'local_government_office',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 734,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia Hentze</a>'],
#      'photo_reference': 'Aap_uEDPwnvaT8H-EafXlG99hnmUF49EOGQt5lhnFS_aiis-7W19UvIgQuIZRShf7cahgCWi3GyFeRysCQycgLrCMzAHjtNsamemVfLj-NNqhhq8kXkMbSWIVUhfMtan2mvpeMKqOjWMm3pzDvfbsLsj46neRzVPwwOgrKMsvMuT7HK7Z_ZE',
#      'width': 3024}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 164,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544535802915,
#       'lng': 2.345997680291501},
#      'southwest': {'lat': 48.85175561970851, 'lng': 2.343299719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEBQjrFUjx86xqqxA1Nr3srWISFrqEm72hVviv61DNpb-uTlbNbVSux9m6kt0Yw3noIcyZVb8qFa5smUwDq-q8u8Yvtb2xiBHczbZ4-UE5RFsliQG8i08dAZgyldVRhVf2KcOqWrc-4NrECW5uOsgg48RPfdLH0C5DyuaQtE8kk9HUmj',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 357,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8532403, 'lng': 2.3457375},
#     'viewport': {'northeast': {'lat': 48.85462748029149,
#       'lng': 2.347175730291502},
#      'southwest': {'lat': 48.8519295197085, 'lng': 2.344477769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Rives de Notre-Dame Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109297776903693488857">Sandro Nardella</a>'],
#      'photo_reference': 'Aap_uEDZVEYLInBfaL439fycHyFBcMqiGl4tYYRB-9M7ih-M1FYkbhQQcFydbOmX2haRN8_CTa0SehilQQ7Mmh2rCNF7_Y7cwPPCLtkgnbLxNomxBwzBknCAV3hkGL74XNm09hhE90rSt7Mm9sHPnvzaCQufiDDfZKtrkkp2a5Rna_tKHrkB',
#      'width': 4032}],
#    'place_id': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'plus_code': {'compound_code': 'V83W+77 Paris, France',
#     'global_code': '8FW4V83W+77'},
#    'rating': 4.5,
#    'reference': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 94,
#    'vicinity': '15 Quai Saint-Michel, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint-Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEBCV7ae5IOUyoq-yj65VemVC1eL8W6u48ofDvAhaL89ZdmfFHkeZsv2vw692vK2B_sJ3DrhGBjTkn63KpEMm7tq6gM5Pvr_o1SeF0HfL3A-8m_mEnwz_Dj0TrvUwQIDRQ826r024Jno4yGBmxza3ryje7HWnY6c42UNHsuyD1LzakMB',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 170,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8518743, 'lng': 2.3463436},
#     'viewport': {'northeast': {'lat': 48.8532481802915,
#       'lng': 2.347596830291502},
#      'southwest': {'lat': 48.8505502197085, 'lng': 2.344898869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Henri IV Rive Gauche',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110759590658386679133">François ART TAPIEZO</a>'],
#      'photo_reference': 'Aap_uED4erzp5-TCPeUgk5oPWdPoNmJl428ygMNtRnUPjC39b3TLD1ml4stAhohdWmOE10XfLaixeM1ysyKLhRyuHAz1nZqeFPjJNltOnCG8_28PGnjuN7Xi04Xb9Q5NvkM6q8x3_9VeO3CBnhfezNJo1wnsVIQ3vK-pDwAS5cnvqKb4tcTZ',
#      'width': 4032}],
#    'place_id': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'plus_code': {'compound_code': 'V82W+PG Paris, France',
#     'global_code': '8FW4V82W+PG'},
#    'rating': 4.5,
#    'reference': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 152,
#    'vicinity': 'Rue Saint-Jacques, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8600866, 'lng': 2.3533543},
#     'viewport': {'northeast': {'lat': 48.86148808029149,
#       'lng': 2.354740780291502},
#      'southwest': {'lat': 48.85879011970849, 'lng': 2.352042819708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Beaubourg',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2684,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115421447635584539926">Hôtel Beaubourg</a>'],
#      'photo_reference': 'Aap_uEA0P8xp6rcXkA7WOwkhMVUNFmaMilJHOD5p4mOwBSz1pffaJPjfEYk6Ooj_W_DoH6_IUR0HbDJS3NyHoSNGuBqlSpi_2Vqd7iCPzZdYlMwpr8zbEG4RpvtAqbgWafyUE7Su1IcgIWOYqlHxf25uR2xFCIzLrbZmBaVuQyrus2zRc6W8',
#      'width': 5937}],
#    'place_id': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'plus_code': {'compound_code': 'V963+28 Paris, France',
#     'global_code': '8FW4V963+28'},
#    'rating': 4.2,
#    'reference': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 151,
#    'vicinity': '11 Rue Simon le Franc, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.859876, 'lng': 2.347049},
#     'viewport': {'northeast': {'lat': 48.8610872802915,
#       'lng': 2.348425880291502},
#      'southwest': {'lat': 48.8583893197085, 'lng': 2.345727919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel Des Ducs D'Anjou",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115209143941459061727">Hotel Des Ducs D&#39;Anjou</a>'],
#      'photo_reference': 'Aap_uEDiiDGiIdpTKAIG5VFhxmrPNIaxgWIvqGU6UvCPTYNu1TOs1ok1jxhjdJX9l8s3cnIHua7KeHkIZ5QkLRYZ9pWqJlgNfAvZ4QVR5wXBlNqMP-G1EGEssVEjLfvBIoSTsLuqvL8OBSfNOn9ZSi3jz1s-JcQitiQ7VElv5awePXhJFKgr',
#      'width': 1352}],
#    'place_id': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'plus_code': {'compound_code': 'V85W+XR Paris, France',
#     'global_code': '8FW4V85W+XR'},
#    'rating': 3.9,
#    'reference': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 319,
#    'vicinity': '1 Rue Sainte-Opportune, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8515237, 'lng': 2.3486679},
#     'viewport': {'northeast': {'lat': 48.8529256302915,
#       'lng': 2.349962130291502},
#      'southwest': {'lat': 48.8502276697085, 'lng': 2.347264169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Maison Colbert Member of Meliá Collection',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3656,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102194778927204133336">Hotel Maison Colbert Member of Meliá Collection</a>'],
#      'photo_reference': 'Aap_uEDGq_zyOb_Xj_bftDW-p6rVbg8DHyCIwRysu9MrOs67pbhE0OWwR-KoeOej52IHpOwweqJ3LcHcPeUKHGUXU_u_5Y0cWrQhsJ4OFTIjtW2S4SaoZLhqmTI5MFbaAugBlfn4JtJfQ4rOujvSApQl0ZEhI4eI7DFFN7AaKcIgqDGQqnYO',
#      'width': 3543}],
#    'place_id': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'plus_code': {'compound_code': 'V82X+JF Paris, France',
#     'global_code': '8FW4V82X+JF'},
#    'rating': 4.4,
#    'reference': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 234,
#    'vicinity': "7 Rue de l'Hôtel Colbert, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499446, 'lng': 2.346247699999999},
#     'viewport': {'northeast': {'lat': 48.8513264802915,
#       'lng': 2.347622530291501},
#      'southwest': {'lat': 48.8486285197085, 'lng': 2.344924569708497}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEB4kKSTGZZeMOfB0pVuBEaUkwo4ti2VAdmwKC27iX9w_h8KGeuQZAz2dYJ57G1ju2xYVSmp0H09qMgIvLPiqtA_XaJ6n6AL-YIi1QXsl2ORgAlFzOuGeM05Lys_dJTlpi43wz80ARc6rjpaC52MDyQHoCgfI8ZM83Is_PKgtumnyQnJ',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 328,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8514465, 'lng': 2.3495407},
#     'viewport': {'northeast': {'lat': 48.85276158029151,
#       'lng': 2.350874680291501},
#      'southwest': {'lat': 48.85006361970851, 'lng': 2.348176719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Degrés de Notre Dame',
#    'photos': [{'height': 1984,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115564994803632359392">christophe etter</a>'],
#      'photo_reference': 'Aap_uEAP28WN5dNEe6_y37dAXZfhInY99xu5zyybuIm-Tv6UtUUiCOX97vA6b2kwyNdXFN7mgamvaWShGe1MZQ_eYa8PgIdgxbSunxsfn3qKO3iyeubR3mVqVkoHrNA4rozZjdfyYxKIVUL_cSDjxKNoayerdy1Y8ikh6XNKY_rYLSfrAH6l',
#      'width': 3968}],
#    'place_id': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'plus_code': {'compound_code': 'V82X+HR Paris, France',
#     'global_code': '8FW4V82X+HR'},
#    'rating': 3.8,
#    'reference': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 78,
#    'vicinity': '10 Rue des Grands Degrés, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85221300000001, 'lng': 2.3420703},
#     'viewport': {'northeast': {'lat': 48.8535826302915,
#       'lng': 2.343484980291502},
#      'southwest': {'lat': 48.8508846697085, 'lng': 2.340787019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Du Lys',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107472282758971290035">Juan pitarch roca</a>'],
#      'photo_reference': 'Aap_uEAeTzLmcKsky5n5Hk-tPPppnoOzMpC3GmwBo-B-gkeeDm-hWo-5-tf2jIxDAOjUbCcMuHcDNU0BueQvmEcS5aHWQKtgasaFRz7BfaypAqYyuOeOSANp0FTx9tIzxHi1kpNdHht1hgtZ_mjq59Rfx2fiZXsRLkA5wvl_MclL0xL6Kl6U',
#      'width': 3024}],
#    'place_id': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'plus_code': {'compound_code': 'V82R+VR Paris, France',
#     'global_code': '8FW4V82R+VR'},
#    'rating': 3.9,
#    'reference': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 230,
#    'vicinity': '23 Rue Serpente, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607212, 'lng': 2.342585},
#     'viewport': {'northeast': {'lat': 48.8620849802915,
#       'lng': 2.343869380291502},
#      'southwest': {'lat': 48.8593870197085, 'lng': 2.341171419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "L'Empire Paris",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1123,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112201701198428774080">L&#39;Empire Paris</a>'],
#      'photo_reference': 'Aap_uEB9TveSt2CHjKhVXvVWeWVZ5XDmo3y0TFCerfo4uGWyRfnC8z4bi4S4OzF1cfWJ3dHW_Yy-RJPnUPqEqcxbdMWGY2hq1mF5jhHBtSxQGw5yJ0kiQE5vWqXGT8Njf0LY-LmOblKJpUGF3phH95foNe59U5D_Ejqcuw708Gz50yBw62EY',
#      'width': 2000}],
#    'place_id': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'plus_code': {'compound_code': 'V86V+72 Paris, France',
#     'global_code': '8FW4V86V+72'},
#    'rating': 4.2,
#    'reference': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 459,
#    'vicinity': "48 Rue de l'Arbre Sec, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85924579999999,
#      'lng': 2.341004799999999},
#     'viewport': {'northeast': {'lat': 48.8606175802915,
#       'lng': 2.342363980291502},
#      'southwest': {'lat': 48.8579196197085, 'lng': 2.339666019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Relais Du Louvre',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113229819060416823993">Constance Fodé</a>'],
#      'photo_reference': 'Aap_uEBJ2epsvYTxT6IXbfNq-vETXLVdV8KPskdtDky4PJIllroSPoDIHB__Cn5e17WWZhSIx5ERHyk7H3uzAMwQkjkyDv7eXnp5yzFu18ZhYGX_1WNmSodfr8ER6b4WAcDgBxb1WWCRihmT68EyQUnw2M2wan487Vm02F2tGKkoPXzfB75r',
#      'width': 4032}],
#    'place_id': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'plus_code': {'compound_code': 'V85R+MC Paris, France',
#     'global_code': '8FW4V85R+MC'},
#    'rating': 4.6,
#    'reference': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 132,
#    'vicinity': "19 Rue des Prêtres Saint-Germain l'Auxerrois, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8632711, 'lng': 2.352693},
#     'viewport': {'northeast': {'lat': 48.86461498029149,
#       'lng': 2.353958580291502},
#      'southwest': {'lat': 48.8619170197085, 'lng': 2.351260619708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Georgette',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1181,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112851757923591367842">Hotel Georgette</a>'],
#      'photo_reference': 'Aap_uECJDiKSa_nN7-dONbl9WpCx1I7-YP3av98lHzUb5Z4p6G60SjWKbj5C_F_RDzUDRVBLR3U0h6wqQA68oy_I8yD7Bu0STvMtxagb2fkcPZZ9D89quFEMEvNhdhAQUjDEe6NCD6kJxd1HWYXq2XQTr149N6NH-wa9Ltfyt1y6Gu29TL4N',
#      'width': 1772}],
#    'place_id': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'plus_code': {'compound_code': 'V973+83 Paris, France',
#     'global_code': '8FW4V973+83'},
#    'rating': 4.4,
#    'reference': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 200,
#    'vicinity': '36 Rue du Grenier-Saint-Lazare, Paris'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#               City Country  Max Temp      Lat       Lng  \
# 0     Puerto Ayora      EC     80.56  -0.7393  -90.3518
# 5             Hilo      US     77.29  19.7297 -155.0900
# 6       Georgetown      MY     80.53   5.4112  100.3354
# 8           Avarua      CK     80.65 -21.2078 -159.7750
# 10         Salalah      OM     80.69  17.0151   54.0924
# ..             ...     ...       ...      ...       ...
# 545    Zhanakorgan      KZ     64.38  43.9098   67.2495
# 548  San Cristobal      VE     80.78   7.7669  -72.2250
# 551      Netrakona      BD     72.36  24.8833   90.7167
# 553       West Bay      KY     85.06  19.3667  -81.4167
# 554         Chamba      IN     63.95  32.5667   76.1333
#
#                                    Hotel Name
# 0                   Finch Bay Galapagos Hotel
# 5                         Hilo Hawaiian Hotel
# 6                              Cititel Penang
# 8                                Paradise Inn
# 10   HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# ..                                        ...
# 545                       "Ақпалас" қонақ үйі
# 548                                  Pirineos
# 551                           Rakib chatrabas
# 553                              Calypso Cove
# 554                   NotOnMap - Rafi's House
#
# [303 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>77.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>80.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Inn</dd>\n<dt>City</dt><dd>Avarua</dd>\n<dt>Country</dt><dd>CK</dd>\n<dt>Max Temp</dt><dd>80.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel</dd>\n<dt>City</dt><dd>Salalah</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Max Temp</dt><dd>80.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ikathouse</dd>\n<dt>City</dt><dd>Komsomolskiy</dd>\n<dt>Country</dt><dd>UZ</dd>\n<dt>Max Temp</dt><dd>69.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotels in Lakshadweep Islands</dd>\n<dt>City</dt><dd>Kavaratti</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>83.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maringe Lagoon Lodge</dd>\n<dt>City</dt><dd>Buala</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>81.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>79.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shanti Maurice Resort & Spa</dd>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>76.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>御宿商旅-中山館</dd>\n<dt>City</dt><dd>Kaohsiung</dd>\n<dt>Country</dt><dd>TW</dd>\n<dt>Max Temp</dt><dd>72.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Broadwater Mariner Resort</dd>\n<dt>City</dt><dd>Geraldton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>66.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>la casona de juancho</dd>\n<dt>City</dt><dd>Puerto Leguizamo</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>84.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Diego De Almagro Coyhaique</dd>\n<dt>City</dt><dd>Coihaique</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>61.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Halyards Hotel</dd>\n<dt>City</dt><dd>Port Alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>62.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>المنزل</dd>\n<dt>City</dt><dd>Awjilah</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Max Temp</dt><dd>75.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Palace Hotel & Spa Durrës</dd>\n<dt>City</dt><dd>Durres</dd>\n<dt>Country</dt><dd>AL</dd>\n<dt>Max Temp</dt><dd>60.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>RH HOTEL (4 Star)</dd>\n<dt>City</dt><dd>Sibu</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>74.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tu Casa</dd>\n<dt>City</dt><dd>East London</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>61.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shandrani Beachcomber Resort & Spa</dd>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>76.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Nusantara I</dd>\n<dt>City</dt><dd>Nabire</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Dora, Bubaque</dd>\n<dt>City</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Max Temp</dt><dd>75.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Tia Villa</dd>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>76.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shishime Hotel</dd>\n<dt>City</dt><dd>Naze</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Max Temp</dt><dd>60.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>People ThankYou</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>77.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Courtyard by Marriott Danbury</dd>\n<dt>City</dt><dd>Bethel</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>66.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Arena Gruesa</dd>\n<dt>City</dt><dd>Ancud</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>63.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Patilla</dd>\n<dt>City</dt><dd>Santa Pola</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Max Temp</dt><dd>70.32 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Nathaniel's Lodge</dd>\n<dt>City</dt><dd>Basco</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>76.24 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>66.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Radhey Heritage</dd>\n<dt>City</dt><dd>Chittaurgarh</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>80.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chambres d\'hôte "La Trinité"</dd>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>74.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Melrose</dd>\n<dt>City</dt><dd>Sambava</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Max Temp</dt><dd>75.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Merauke</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>76.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Tokyo Vihar</dd>\n<dt>City</dt><dd>Bodh Gaya</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>83.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Radisson Blu Hotel Waterfront, Cape Town</dd>\n<dt>City</dt><dd>Cape Town</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>60.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Le Dronmi</dd>\n<dt>City</dt><dd>Cayenne</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Max Temp</dt><dd>82.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Coconut Beach Resort</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>80.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Miramar</dd>\n<dt>City</dt><dd>Huarmey</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>71.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Moon light Furnished Units</dd>\n<dt>City</dt><dd>Umm Lajj</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>80.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scarborough Beach Resort</dd>\n<dt>City</dt><dd>Redcliffe</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>65.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Max Temp</dt><dd>81.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>73.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gran Hotel Mar del Plata</dd>\n<dt>City</dt><dd>Mar Del Plata</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>66.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ahipara Holiday Park</dd>\n<dt>City</dt><dd>Ahipara</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Max Temp</dt><dd>65.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Chik Chik Namibe</dd>\n<dt>City</dt><dd>Namibe</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Max Temp</dt><dd>74.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le gîte du Koniambo</dd>\n<dt>City</dt><dd>Voh</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>75.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LÜDERITZ NEST HOTEL</dd>\n<dt>City</dt><dd>Luderitz</dd>\n<dt>Country</dt><dd>nan</dd>\n<dt>Max Temp</dt><dd>64.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Gaoua</dd>\n<dt>Country</dt><dd>BF</dd>\n<dt>Max Temp</dt><dd>78.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Akash</dd>\n<dt>City</dt><dd>Rampura</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>81.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Agadez</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Max Temp</dt><dd>83.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mini Hotel Central</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Max Temp</dt><dd>71.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pestana Bahia Praia</dd>\n<dt>City</dt><dd>Vila Franca Do Campo</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>61.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HS Hotsson Smart Acapulco</dd>\n<dt>City</dt><dd>Acapulco</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>85.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>39 On Nile Guest House</dd>\n<dt>City</dt><dd>Port Elizabeth</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>63.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Storyboard Beach Resort</dd>\n<dt>City</dt><dd>Kloulklubed</dd>\n<dt>Country</dt><dd>PW</dd>\n<dt>Max Temp</dt><dd>82.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitória Palace</dd>\n<dt>City</dt><dd>Vila Velha</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>76.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Villa Kitzia Huacho</dd>\n<dt>City</dt><dd>Hualmay</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>70.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oyster Box Guesthouse</dd>\n<dt>City</dt><dd>Walvis Bay</dd>\n<dt>Country</dt><dd>nan</dd>\n<dt>Max Temp</dt><dd>61.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dhidhoo beach</dd>\n<dt>City</dt><dd>Dhidhdhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>84.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>conjunto pradera</dd>\n<dt>City</dt><dd>Pradera</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>73.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ambika Hotel & Cold drinks</dd>\n<dt>City</dt><dd>Balapur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>87.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>محمد هادي ال فطيح</dd>\n<dt>City</dt><dd>Najran</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>79.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paradise Bay Resort</dd>\n<dt>City</dt><dd>Ahuimanu</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>79.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>84.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CeBlue Villas & Beach Resort</dd>\n<dt>City</dt><dd>The Valley</dd>\n<dt>Country</dt><dd>AI</dd>\n<dt>Max Temp</dt><dd>80.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Farah</dd>\n<dt>Country</dt><dd>AF</dd>\n<dt>Max Temp</dt><dd>69.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Lusambo</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Max Temp</dt><dd>70.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Terranea Resort</dd>\n<dt>City</dt><dd>Rancho Palos Verdes</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>71.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Flat Quatro Rodas Olinda</dd>\n<dt>City</dt><dd>Olinda</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>83.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vila Galé Cascais</dd>\n<dt>City</dt><dd>Cascais</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>61.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quinta da Meia Eira</dd>\n<dt>City</dt><dd>Ribeira Grande</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>60.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aridolf Resort Wellness and Spa</dd>\n<dt>City</dt><dd>Yenagoa</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>78.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Renaissance Naples Hotel Mediterraneo</dd>\n<dt>City</dt><dd>Naples</dd>\n<dt>Country</dt><dd>IT</dd>\n<dt>Max Temp</dt><dd>66.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Rio Current</dd>\n<dt>City</dt><dd>Santa Maria Da Vitoria</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>73.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Tesoro Los Cabos</dd>\n<dt>City</dt><dd>Cabo San Lucas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>89.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vila Nova Hotel</dd>\n<dt>City</dt><dd>Ponta Delgada</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>61.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>82.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Atlântico Rio Grande</dd>\n<dt>City</dt><dd>Rio Grande</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>68.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Boutique Las Azucenas</dd>\n<dt>City</dt><dd>Constitucion</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>61.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Citra</dd>\n<dt>City</dt><dd>Sabang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>83.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>73.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Windy Lodge & Beach Resort</dd>\n<dt>City</dt><dd>Winneba</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Max Temp</dt><dd>79.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Desert Gardens Hotel - Ayers Rock Resort</dd>\n<dt>City</dt><dd>Yulara</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>69.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>فندق أوباري</dd>\n<dt>City</dt><dd>Awbari</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Max Temp</dt><dd>69.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Fifu</dd>\n<dt>City</dt><dd>Jaisalmer</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>84.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Arrarte</dd>\n<dt>City</dt><dd>Rocha</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Max Temp</dt><dd>60.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Regency Hotel</dd>\n<dt>City</dt><dd>Yanam</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>79.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa de Provincia</dd>\n<dt>City</dt><dd>Candelaria</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>74.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Grace Hôtel</dd>\n<dt>City</dt><dd>Kribi</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Max Temp</dt><dd>78.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Humacao Bed & Breakfast</dd>\n<dt>City</dt><dd>Vallenar</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>73.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>TDC Village (Hundred Man Camp)</dd>\n<dt>City</dt><dd>Port Keats</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>77.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oumou Elghoura</dd>\n<dt>City</dt><dd>Atar</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>84.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Eastgate Hotel</dd>\n<dt>City</dt><dd>Kapoeta</dd>\n<dt>Country</dt><dd>SS</dd>\n<dt>Max Temp</dt><dd>70.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Winner Hotel Pemalang</dd>\n<dt>City</dt><dd>Pemalang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Adrar</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>83.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Gualberto - Deysi</dd>\n<dt>City</dt><dd>Bahia Honda</dd>\n<dt>Country</dt><dd>CU</dd>\n<dt>Max Temp</dt><dd>83.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Expeditions Ténére voyages</dd>\n<dt>City</dt><dd>Bilma</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Max Temp</dt><dd>89.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sainik Rest House</dd>\n<dt>City</dt><dd>Jhajjar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Reserva do Abiaí</dd>\n<dt>City</dt><dd>Pitimbu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>82.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ibis Styles Mt Isa Verona</dd>\n<dt>City</dt><dd>Mount Isa</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>62.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aviador Hotel Boutique</dd>\n<dt>City</dt><dd>Santa Cruz</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>72.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge les abou</dd>\n<dt>City</dt><dd>Fomboni</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Max Temp</dt><dd>83.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Puerto Delta Apartamentos</dd>\n<dt>City</dt><dd>Tigre</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>69.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Castle Motor Lodge Motel</dd>\n<dt>City</dt><dd>Bowen</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>71.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Codrington Gardens Bed And Breakfast</dd>\n<dt>City</dt><dd>Codrington</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>67.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>صاحبة الفخامة</dd>\n<dt>City</dt><dd>Jalu</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Max Temp</dt><dd>78.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Spanish Villa</dd>\n<dt>City</dt><dd>Mumford</dd>\n<dt>Country</dt><dd>GH</dd>\n<dt>Max Temp</dt><dd>79.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge du 11 décembre de la cité CNSS à Manga</dd>\n<dt>City</dt><dd>Manga</dd>\n<dt>Country</dt><dd>BF</dd>\n<dt>Max Temp</dt><dd>84.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel El Recreo</dd>\n<dt>City</dt><dd>General Roca</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>71.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Otel Alabanda</dd>\n<dt>City</dt><dd>Cine</dd>\n<dt>Country</dt><dd>TR</dd>\n<dt>Max Temp</dt><dd>60.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 2722 Lemon Residence Prabumulih</dd>\n<dt>City</dt><dd>Prabumulih</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>72.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuevo Hotel Plaza</dd>\n<dt>City</dt><dd>Chuy</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Max Temp</dt><dd>63.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Prespter Royal Dutch</dd>\n<dt>City</dt><dd>Ikot Ekpene</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>80.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Ramela Hotel</dd>\n<dt>City</dt><dd>Kisangani</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Max Temp</dt><dd>69.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Xaguate</dd>\n<dt>City</dt><dd>Sao Filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n<dt>Max Temp</dt><dd>71.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Jared Coffin House</dd>\n<dt>City</dt><dd>Nantucket</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>60.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Mercure Danang</dd>\n<dt>City</dt><dd>Da Nang</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>78.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Backpacker`s Hostel Iquique</dd>\n<dt>City</dt><dd>Iquique</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>68.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Condall Palace Hotel</dd>\n<dt>City</dt><dd>Nova Prata</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>60.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hotel la terminal</dd>\n<dt>City</dt><dd>Ixtapa</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>79.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Beso del Viento</dd>\n<dt>City</dt><dd>Parrita</dd>\n<dt>Country</dt><dd>CR</dd>\n<dt>Max Temp</dt><dd>85.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Toko pakaian bu is Tayu</dd>\n<dt>City</dt><dd>Tayu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>77.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sea Lounge! Bar, Club & Restaurant</dd>\n<dt>City</dt><dd>Itarema</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>79.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Balihai Bungalows</dd>\n<dt>City</dt><dd>Chicama</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>74.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kamana</dd>\n<dt>City</dt><dd>Lima</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>69.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Lossandes</dd>\n<dt>City</dt><dd>Carmen</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>89.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DoubleFAG</dd>\n<dt>City</dt><dd>Labuhan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>78.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>املاك خالد الشعشوع</dd>\n<dt>City</dt><dd>Faya</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>66.72 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Abu Samrah</dd>\n<dt>Country</dt><dd>SY</dd>\n<dt>Max Temp</dt><dd>60.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel La Giralda</dd>\n<dt>City</dt><dd>Nador</dd>\n<dt>Country</dt><dd>MA</dd>\n<dt>Max Temp</dt><dd>64.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Plus Abbey Inn</dd>\n<dt>City</dt><dd>Saint George</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>81.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel Salama</dd>\n<dt>City</dt><dd>Moussoro</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Max Temp</dt><dd>88.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Esplanade Hotel</dd>\n<dt>City</dt><dd>Port Hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>73.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Piaçabuçu News</dd>\n<dt>City</dt><dd>Piacabucu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Kalengwa</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Max Temp</dt><dd>64.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>VS Villa</dd>\n<dt>City</dt><dd>Kalmunai</dd>\n<dt>Country</dt><dd>LK</dd>\n<dt>Max Temp</dt><dd>79.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Camp Pālehua</dd>\n<dt>City</dt><dd>Nanakuli</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Crôa Mares Hotel</dd>\n<dt>City</dt><dd>Sao Jose Da Coroa Grande</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>81.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ompoy Pension House</dd>\n<dt>City</dt><dd>Kalawit</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Max Temp</dt><dd>77.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>نیک سرشت</dd>\n<dt>City</dt><dd>Iranshahr</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Max Temp</dt><dd>84.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Desert Palms Alice Springs</dd>\n<dt>City</dt><dd>Alice Springs</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>71.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada del Inti Centro</dd>\n<dt>City</dt><dd>Mercedes</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>68.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel & Restaurant DIANA Ambilobe</dd>\n<dt>City</dt><dd>Ambilobe</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Max Temp</dt><dd>72.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mavillah Apartment and Suites</dd>\n<dt>City</dt><dd>Gboko</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>87.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kashmiri Hotal</dd>\n<dt>City</dt><dd>Pasni</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Max Temp</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oyster Bay House Rental</dd>\n<dt>City</dt><dd>Kruisfontein</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>60.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Max Temp</dt><dd>83.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kununurra</dd>\n<dt>City</dt><dd>Kununurra</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>75.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Miami Apart Hotel</dd>\n<dt>City</dt><dd>Miracema Do Tocantins</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>76.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Umm Kaddadah</dd>\n<dt>Country</dt><dd>SD</dd>\n<dt>Max Temp</dt><dd>83.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel FX 72</dd>\n<dt>City</dt><dd>Ruteng</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>62.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Valle Aridane</dd>\n<dt>City</dt><dd>Los Llanos De Aridane</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Max Temp</dt><dd>65.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Casino San Eugenio del Cuareim</dd>\n<dt>City</dt><dd>Artigas</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Max Temp</dt><dd>63.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Khonsa</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>60.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada dos Navegantes</dd>\n<dt>City</dt><dd>Caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>77.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Festival Plaza Rosarito</dd>\n<dt>City</dt><dd>Rosarito</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>73.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fengshui Residence</dd>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Osprey Beach Hotel</dd>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Max Temp</dt><dd>77.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>BON Hotel Waterfront Richards Bay</dd>\n<dt>City</dt><dd>Richards Bay</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Max Temp</dt><dd>63.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheffield House Bed & Breakfast</dd>\n<dt>City</dt><dd>Kailua</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>80.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Arena Blanca</dd>\n<dt>City</dt><dd>San Andres</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>86.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>El Medina</dd>\n<dt>City</dt><dd>Nouadhibou</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>64.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Residencial Karime</dd>\n<dt>City</dt><dd>Taltal</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>64.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Reindeer Resort Kanatal</dd>\n<dt>City</dt><dd>Tehri</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>65.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kou-Bugny</dd>\n<dt>City</dt><dd>Vao</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>76.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vahmoneh Lodge Vanimo</dd>\n<dt>City</dt><dd>Vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>77.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pacifica Lighthouse, Trademark Collection by Wyndham</dd>\n<dt>City</dt><dd>Pacifica</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>65.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Zabol</dd>\n<dt>Country</dt><dd>AF</dd>\n<dt>Max Temp</dt><dd>65.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Leumerus Bungalows</dd>\n<dt>City</dt><dd>Sola</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL IMAN</dd>\n<dt>City</dt><dd>Nouakchott</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Max Temp</dt><dd>60.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Beachfront Voyager Motor Inn</dd>\n<dt>City</dt><dd>Burnie</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>60.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Residence Inn by Marriott Gulfport-Biloxi Airport</dd>\n<dt>City</dt><dd>Harrison</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>84.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bora-Bora Pearl Beach Resort & Spa</dd>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>82.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Paihuen</dd>\n<dt>City</dt><dd>Buin</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>73.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto De Canoas</dd>\n<dt>City</dt><dd>Sao Joao Da Barra</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>75.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lindsey Hôtel</dd>\n<dt>City</dt><dd>Saint-Pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>74.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gurukarpa Hotel</dd>\n<dt>City</dt><dd>Nokha</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shwe Pyi Soe Guest House, Thaton</dd>\n<dt>City</dt><dd>Thaton</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Max Temp</dt><dd>81.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Castelo</dd>\n<dt>City</dt><dd>Cidreira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>66.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Resorts Resource Group International</dd>\n<dt>City</dt><dd>Mayo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Baza Zika</dd>\n<dt>City</dt><dd>Karatau</dd>\n<dt>Country</dt><dd>KZ</dd>\n<dt>Max Temp</dt><dd>61.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada Lilia</dd>\n<dt>City</dt><dd>Celestun</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>83.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Esperance</dd>\n<dt>City</dt><dd>Esperance</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>63.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Phama Lodge</dd>\n<dt>City</dt><dd>Mocuba</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Max Temp</dt><dd>70.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kandamba</dd>\n<dt>City</dt><dd>Luena</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Max Temp</dt><dd>61.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Balandra Hotel</dd>\n<dt>City</dt><dd>Manta</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>83.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel JM Puerto del Rosario</dd>\n<dt>City</dt><dd>Puerto Del Rosario</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Max Temp</dt><dd>67.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Wedgewood Motel</dd>\n<dt>City</dt><dd>Palmer</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>62.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>900 Boutique INN</dd>\n<dt>City</dt><dd>Bintulu</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>79.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ibis Styles Karratha</dd>\n<dt>City</dt><dd>Karratha</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>82.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dillon Express Inn</dd>\n<dt>City</dt><dd>Dillon</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>77.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Trinity Plains Tourist Park</dd>\n<dt>City</dt><dd>Mareeba</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>70.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Baherden</dd>\n<dt>Country</dt><dd>TM</dd>\n<dt>Max Temp</dt><dd>61.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Six Acres Bed & Breakfast</dd>\n<dt>City</dt><dd>Hamilton</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>63.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel On The Rock by Prasanthi</dd>\n<dt>City</dt><dd>Kupang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>77.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le Clos Du Pontic</dd>\n<dt>City</dt><dd>Landerneau</dd>\n<dt>Country</dt><dd>FR</dd>\n<dt>Max Temp</dt><dd>61.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Commodore</dd>\n<dt>City</dt><dd>Mount Gambier</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>68.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Sayat</dd>\n<dt>Country</dt><dd>TM</dd>\n<dt>Max Temp</dt><dd>69.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aldea del Bazar Hotel and Spa</dd>\n<dt>City</dt><dd>Puerto Escondido</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>86.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Garachine</dd>\n<dt>Country</dt><dd>PA</dd>\n<dt>Max Temp</dt><dd>83.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nile Palace Hotel</dd>\n<dt>City</dt><dd>Malakal</dd>\n<dt>Country</dt><dd>SS</dd>\n<dt>Max Temp</dt><dd>83.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Sembe</dd>\n<dt>Country</dt><dd>CG</dd>\n<dt>Max Temp</dt><dd>75.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maqna Hotel by Prasanthi</dd>\n<dt>City</dt><dd>Gorontalo</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>74.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Complejo Turístico Farelluk</dd>\n<dt>City</dt><dd>San Vicente</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>62.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quitanda santos</dd>\n<dt>City</dt><dd>Ibipeba</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>75.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Mar Colina</dd>\n<dt>City</dt><dd>Yeppoon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>65.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL QUINTA ANTIGUA</dd>\n<dt>City</dt><dd>Lazaro Cardenas</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>83.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Toledo</dd>\n<dt>City</dt><dd>Capiibary</dd>\n<dt>Country</dt><dd>PY</dd>\n<dt>Max Temp</dt><dd>67.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal El Tiempo</dd>\n<dt>City</dt><dd>Huaral</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>70.79 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aderemi Guest Garden</dd>\n<dt>City</dt><dd>Gbongan</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>76.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>81.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sanjrani House</dd>\n<dt>City</dt><dd>Dalbandin</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Max Temp</dt><dd>80.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Whispering Bamboo Cove Resort</dd>\n<dt>City</dt><dd>Morant Bay</dd>\n<dt>Country</dt><dd>JM</dd>\n<dt>Max Temp</dt><dd>82.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hampton Inn Elizabeth City</dd>\n<dt>City</dt><dd>Elizabeth City</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>74.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Port Lincoln Hotel</dd>\n<dt>City</dt><dd>Port Lincoln</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>65.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>77.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sabindo Hotel</dd>\n<dt>City</dt><dd>Keningau</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Max Temp</dt><dd>69.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Antofagasta, an IHG Hotel</dd>\n<dt>City</dt><dd>Antofagasta</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Max Temp</dt><dd>63.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>فندق الفردوس</dd>\n<dt>City</dt><dd>Darnah</dd>\n<dt>Country</dt><dd>LY</dd>\n<dt>Max Temp</dt><dd>66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge du Routard</dd>\n<dt>City</dt><dd>Oussouye</dd>\n<dt>Country</dt><dd>SN</dd>\n<dt>Max Temp</dt><dd>73.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel des hotes</dd>\n<dt>City</dt><dd>Tiassale</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Max Temp</dt><dd>76.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Heritage Park Hotel</dd>\n<dt>City</dt><dd>Honiara</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>79.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Obelisco</dd>\n<dt>City</dt><dd>Cobija</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>82.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Laguna, Bed & Breakfast</dd>\n<dt>City</dt><dd>Guerrero Negro</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Max Temp</dt><dd>67.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Biscayne Suites</dd>\n<dt>City</dt><dd>Ocean City</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Equi-lodge de Moindou</dd>\n<dt>City</dt><dd>Moindou</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>75.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>สถานที่จัดงานแต่ง SOFEE & DORN</dd>\n<dt>City</dt><dd>Yaring</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Max Temp</dt><dd>80.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Timos Transit House</dd>\n<dt>City</dt><dd>Popondetta</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>75.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>R&B Bungalow</dd>\n<dt>City</dt><dd>Machilipatnam</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel do Campo</dd>\n<dt>City</dt><dd>Ponta Do Sol</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Max Temp</dt><dd>72.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Firdaus Society</dd>\n<dt>City</dt><dd>Lakhtar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>82.63 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel</dd>\n<dt>City</dt><dd>Laguna</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>68.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Saigon-PT</dd>\n<dt>City</dt><dd>Phan Thiet</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Max Temp</dt><dd>77.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Inn at Longshore</dd>\n<dt>City</dt><dd>Westport</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>67.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Footscray Motor Inn</dd>\n<dt>City</dt><dd>Seddon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Max Temp</dt><dd>64.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le Rocher de Tahiti</dd>\n<dt>City</dt><dd>Tiarei</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>86.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Laurel Inn & Conference Center</dd>\n<dt>City</dt><dd>Salinas</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>64.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Sibut</dd>\n<dt>Country</dt><dd>CF</dd>\n<dt>Max Temp</dt><dd>78.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Avera</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>72.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>San Borja</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Max Temp</dt><dd>82.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Frena Lodge</dd>\n<dt>City</dt><dd>Kerema</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>78.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Alejandro I</dd>\n<dt>City</dt><dd>Salta</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>67.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Deluxe</dd>\n<dt>City</dt><dd>Quetta</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Max Temp</dt><dd>67.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Solmar Gracious Hotel</dd>\n<dt>City</dt><dd>Lodwar</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Max Temp</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Case de Passage De la Prefecture</dd>\n<dt>City</dt><dd>Arlit</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shwe Eain Matt highly cool guest house</dd>\n<dt>City</dt><dd>Paungde</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Max Temp</dt><dd>84.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>"AFROSIYOB" HOSTEL</dd>\n<dt>City</dt><dd>Kogon</dd>\n<dt>Country</dt><dd>UZ</dd>\n<dt>Max Temp</dt><dd>66.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nuba Nile</dd>\n<dt>City</dt><dd>Aswan</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Max Temp</dt><dd>85.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest House HESADA</dd>\n<dt>City</dt><dd>Angoche</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Max Temp</dt><dd>79.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 884 Rumoh PMI Hotel</dd>\n<dt>City</dt><dd>Banda Aceh</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>80.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ungoofaaru Inn</dd>\n<dt>City</dt><dd>Ugoofaaru</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Max Temp</dt><dd>83.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tanna Lodge</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>87.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>16 Washburn Street Watertown MA</dd>\n<dt>City</dt><dd>Watertown</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>66.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel</dd>\n<dt>City</dt><dd>Makokou</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Max Temp</dt><dd>74.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Bate</dd>\n<dt>City</dt><dd>Kankan</dd>\n<dt>Country</dt><dd>GN</dd>\n<dt>Max Temp</dt><dd>88.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SpringHill Suites by Marriott Baltimore Downtown/Inner Harbor</dd>\n<dt>City</dt><dd>Baltimore</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>79.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ballast Wilmington, Tapestry Collection by Hilton</dd>\n<dt>City</dt><dd>Wilmington</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>73.31 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pereybere Hotel & Spa</dd>\n<dt>City</dt><dd>Cap Malheureux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Max Temp</dt><dd>76.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>"Plantation Bed and Breakfast</dd>\n<dt>City</dt><dd>Saint-Joseph</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Max Temp</dt><dd>72.21 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Taoudenni</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Max Temp</dt><dd>81.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SpringHill Suites by Marriott Ridgecrest</dd>\n<dt>City</dt><dd>Ridgecrest</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>71.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Mounia Fès</dd>\n<dt>City</dt><dd>Fez</dd>\n<dt>Country</dt><dd>MA</dd>\n<dt>Max Temp</dt><dd>61.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>West Plains Motel</dd>\n<dt>City</dt><dd>West Plains</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>60.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Vilia Hotel</dd>\n<dt>City</dt><dd>Tual</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>83.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>unidiversidad organica la utopia</dd>\n<dt>City</dt><dd>Miranda</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Max Temp</dt><dd>77.13 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dallas Hotel Tucuman</dd>\n<dt>City</dt><dd>Tucuman</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>71.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Disney’s Hilton Head Island Resort</dd>\n<dt>City</dt><dd>Hilton Head Island</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>77.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Eco</dd>\n<dt>City</dt><dd>Lagunas</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>84.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Welcomhotel By ITC Hotels, Bay Island, Port Blair</dd>\n<dt>City</dt><dd>Port Blair</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>78.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Жанаргул</dd>\n<dt>City</dt><dd>Chardara</dd>\n<dt>Country</dt><dd>KZ</dd>\n<dt>Max Temp</dt><dd>67.26 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Praia Morena</dd>\n<dt>City</dt><dd>Benguela</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Max Temp</dt><dd>76.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ENCEIN BUREAU CISCO</dd>\n<dt>City</dt><dd>Ankazoabo</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Max Temp</dt><dd>74.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Nobre Palace</dd>\n<dt>City</dt><dd>Teofilo Otoni</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>68.97 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Requinte Hotel</dd>\n<dt>City</dt><dd>Altamira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>86.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Meadowbrook Oaks Mobile Home Park</dd>\n<dt>City</dt><dd>Butte</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>64.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Isidro Oficial</dd>\n<dt>City</dt><dd>Pisco</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Max Temp</dt><dd>70.02 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>InterContinental Riyadh, an IHG Hotel</dd>\n<dt>City</dt><dd>Riyadh</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Max Temp</dt><dd>75.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest House Florvia</dd>\n<dt>City</dt><dd>Kamina</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Max Temp</dt><dd>64.87 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Dry Creek Inn</dd>\n<dt>City</dt><dd>Healdsburg</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>70.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Minshuku Agaihama</dd>\n<dt>City</dt><dd>Nishihara</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Max Temp</dt><dd>65.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Montana Hotel Syariah</dd>\n<dt>City</dt><dd>Martapura</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>71.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Protea Hotel by Marriott Zambezi River Lodge</dd>\n<dt>City</dt><dd>Sesheke</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Max Temp</dt><dd>68.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fishermans Guest House</dd>\n<dt>City</dt><dd>Henties Bay</dd>\n<dt>Country</dt><dd>nan</dd>\n<dt>Max Temp</dt><dd>60.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Screensaver</dd>\n<dt>City</dt><dd>Harper</dd>\n<dt>Country</dt><dd>LR</dd>\n<dt>Max Temp</dt><dd>79.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pinheiros Hotel</dd>\n<dt>City</dt><dd>Sao Jose Do Calcado</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Max Temp</dt><dd>68.58 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kasakchiya Luxury Suites</dd>\n<dt>City</dt><dd>Karia</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Max Temp</dt><dd>89.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Max Temp</dt><dd>82.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guesthouse Samotina</dd>\n<dt>City</dt><dd>Pemba</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Max Temp</dt><dd>79.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SanBiz Lodge</dd>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>82.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Spendwise furnished apartments.</dd>\n<dt>City</dt><dd>Lilongwe</dd>\n<dt>Country</dt><dd>MW</dd>\n<dt>Max Temp</dt><dd>64.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lovers Point Inn</dd>\n<dt>City</dt><dd>Pacific Grove</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>62.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lorengau Harbourside Hotel</dd>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Max Temp</dt><dd>81.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Santa Paula Inn</dd>\n<dt>City</dt><dd>Santa Paula</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>72.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Moissala</dd>\n<dt>Country</dt><dd>TD</dd>\n<dt>Max Temp</dt><dd>89.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Hotel</dd>\n<dt>City</dt><dd>Reconquista</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Max Temp</dt><dd>67.41 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>"Ақпалас" қонақ үйі</dd>\n<dt>City</dt><dd>Zhanakorgan</dd>\n<dt>Country</dt><dd>KZ</dd>\n<dt>Max Temp</dt><dd>64.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pirineos</dd>\n<dt>City</dt><dd>San Cristobal</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Max Temp</dt><dd>80.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rakib chatrabas</dd>\n<dt>City</dt><dd>Netrakona</dd>\n<dt>Country</dt><dd>BD</dd>\n<dt>Max Temp</dt><dd>72.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Calypso Cove</dd>\n<dt>City</dt><dd>West Bay</dd>\n<dt>Country</dt><dd>KY</dd>\n<dt>Max Temp</dt><dd>85.06 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>NotOnMap - Rafi's House</dd>\n<dt>City</dt><dd>Chamba</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>63.95 °F</dd>\n</dl>\n"]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
